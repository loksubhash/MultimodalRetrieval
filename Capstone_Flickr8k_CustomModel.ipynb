# %%
# !pip install -q timm pandas tqdm albumentations opencv-python scikit-learn transformers torch torchvision torchaudio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.5 MB/s eta 0:00:00

# %%
import os
import cv2
import numpy as np
import pandas as pd
import itertools # For optimizer params later
from tqdm.autonotebook import tqdm
import albumentations as A
import matplotlib.pyplot as plt # For potential plotting, not explicitly used in core logic yet
import torch
from torch import nn
import torch.nn.functional as F
import timm
from transformers import DistilBertModel, DistilBertConfig, DistilBertTokenizer
from collections import defaultdict # For metric calculation later
import numpy as np
# Out:
# <ipython-input-2-3b87f105cc95>:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import torch
print(torch.__version__)
# Out:
# 2.6.0+cu124

# %% [markdown]
# ### Block 1: Flickr8k Data Preparation & Initial Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path1 = '/content/drive/MyDrive/Flickr8k.zip'

# !ls -lh "$zip_path1"

# !unzip -q "$zip_path1" -d "/content/sample_data/Flickr8k"
# Out:
# -rw------- 1 root root 1.1G Jun  1 06:35 /content/drive/MyDrive/Flickr8k.zip

# %%
#!mv  "/kaggle/input/flickr8k/" "/content/sample_data/"
# Out:
# Streaming output truncated to the last 5000 lines.
# mv: cannot remove '/kaggle/input/flickr8k/Images/2925242998_9e0db9b4a2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2969380952_9f1eb7f93b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/444845904_a4531c811a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3355827928_c96c0c3e88.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3150440350_b0f2a9e774.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3613705104_46d854134e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3712742641_641282803e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2922512807_d382528a93.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3323952123_deb50b0629.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3144705706_391d7b77c7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3590653633_495de5f288.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/421730441_6b2267fd31.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3647170476_0fd71a4c9f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2432061076_0955d52854.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1798215547_ef7ad95be8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1262077938_8b9516c273.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3480379024_545e8ec818.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/93922153_8d831f7f01.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3670918456_68631d362a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3141613533_595723208d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3286045254_696c6b15bd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2380464803_a64f05bfa9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3340857141_85d97a7466.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2107837987_ffecfc367a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3441511444_b031585b45.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1112212364_0c48235fc2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3167365436_c379bda282.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2238019823_79318d1f11.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2845845721_d0bc113ff7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3593392955_a4125087f6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2977379863_2e8d7a104e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1251558317_4ef844b775.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2073756099_7e02c0110c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3739833689_a0038545bd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3691670743_0ed111bcf3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3503689049_63212220be.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2522540026_6ee8ab4c6a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/413737417_b0a8b445e9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/535399240_0714a6e950.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2994205788_f8b3f2e840.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2584957647_4f9235c150.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3338217927_3c5cf3f7c6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3084011664_76d37c6559.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2891617125_f939f604c7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3482974845_db4f16befa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3470008804_0ca36a7a09.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3478176372_7c510a0cef.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1490670858_e122df2560.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3259002340_707ce96858.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2857473929_4f52662c30.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3043904009_3b5e0412cd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2649406158_ded6be38de.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3716244806_97d5a1fb61.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2060031241_a3ae7a06bb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3111402233_6285bcba7a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3239480519_22540b5016.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2500354186_0836309cc9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2632381125_de32bdfdf6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2410562803_56ec09f41c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3323498985_fd9d2803fd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2114126343_a0f74ff63b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3053415073_5b667230ed.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3424851862_0f51c42922.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3583321426_f373c52161.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2834103050_512e5b330a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3643684688_2f7157b23d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2322593776_e6aaf69e80.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2976155358_b4dd4407cf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/772403830_08b72c7da9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/359837950_9e22ffe6c2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/442220883_ff3d6e507f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2698487246_e827404cac.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3443853670_6c79fcfcb2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3463523977_f2ed231585.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2510197716_fddca0ac75.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/457945610_1a23b9ced0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2435166927_28b8130660.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3404978479_8a81843e17.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3425887426_bf60b8afa3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2261346505_302c67951d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3468023754_8a07d4c56e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/289616152_012a9f16c6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3654338683_13b2f95a9a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/224026428_0165164ceb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/514431934_9cf78f05a9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2458269558_277012780d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3051341320_1d0166e775.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2428086758_bce4733f7e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/535529555_583d89b7f2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3019923691_3b3c5a4766.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3046286572_d2050ab0d9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3149804151_1cc8d10783.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2949497756_be8e58e6bd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/241347204_007d83e252.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3286017638_c688c83e3d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3398276602_c7d106c34f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3695517194_2a6b604cb2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2301867590_98c0ecb0cb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2868136205_3cf679208d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/267164457_2e8b4d30aa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/199463720_329a802206.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/189740668_0b045f1ff2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2773400732_5b65a25857.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3504158556_1d410c8ff7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1088767354_2acee738cf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1445123245_c7b9db0e0c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3710468717_c051d96a5f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3220009216_10f088185e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1387461595_2fe6925f73.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2075041394_0b3ea1822d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/317488612_70ac35493b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3136043366_b3f8607a0e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3262301835_9f1a49b80a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/543326592_70bd4d8602.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3669069522_555c97fbfb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/610590753_cd69ce081a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2693425189_47740c22ed.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3744832122_2f4febdff6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3341477531_4e37450f35.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3618908551_7fd2de5710.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3107889179_106d223345.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2922973230_5a769ef92a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3126225245_96cd2c053f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1351764581_4d4fb1b40f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1117972841_2b9261f95f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2591603141_33d6397e0a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2890075175_4bd32b201a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/166507476_9be5b9852a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3377570617_d2f2225a74.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/795081510_53fd17d101.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3383545083_1d7c95b003.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/195962284_e57178054a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3457856049_2de173e818.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/405537503_f66ecc5073.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/515702827_be3c6ce857.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2868575889_2c030aa8ae.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3145967019_1a83ebf712.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2992999413_018f48aabc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2649705487_4605e879e9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3110174991_a4b05f8a46.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1773928579_5664a810dc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3474985382_26e1560338.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2214847438_4993210d4c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2126950128_74a4882658.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2041867793_552819a40b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/445655284_c29e6d7323.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3296226598_1c892c4351.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3511062827_cd87871c67.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/233361142_d9d5f0cae9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3319405494_58dee86b21.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3694071771_ce760db4c7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1354318519_2f9baed754.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2667783499_3a4f38f636.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2970183443_accd597e0a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3077781040_bc27778609.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3420323191_d66e003264.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3268407162_6274e0f74f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3677329561_fa3e1fdcf9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/583087629_a09334e1fb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2004674713_2883e63c67.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2274992140_bb9e868bb8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3533470072_87a5b595ba.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1552065993_b4dcd2eadf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3440160917_4524cfd9f6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/41999070_838089137e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3123770450_cedc16d162.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1159574340_99ba8c3c59.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/224766705_b77996527f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3544803461_a418ca611e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2502782508_2c8211cd6b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3636126441_5617c89aaa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1465666502_de289b3b9c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/276356412_dfa01c3c9e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2501968935_02f2cd8079.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3459362347_c412ef9901.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3497237366_366997495d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3708748633_e7e3cf4e84.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3518126579_e70e0cbb2b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3577309234_c952c2af86.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3456579559_b5c8927938.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2980118787_2099de53ec.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/410413536_11f1127c46.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1082379191_ec1e53f996.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2176874361_2b4149010b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1473618073_7db56a5237.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/264928854_d9e61f3a8e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3453259666_9ecaa8bb4b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1572532018_64c030c974.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/491405109_798222cfd0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3640329164_20cb245fd5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3634785801_4b23184a06.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2439813616_c9ac54cc9f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2519812011_f85c3b5cb5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2240539658_dea8db6e55.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2672354635_3a03f76486.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/197924859_f6e39a7dfa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3677318686_b018862bb7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/211295363_49010ca38d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2477623312_58e8e8c8af.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3170551725_1276644eab.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3057770908_3fd97f79f9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2297471897_3419605c16.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2975253472_0f0c2dea70.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3431671749_e8e3a449ac.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3289893683_d4cc3ce208.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1067180831_a59dc64344.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3642220260_3aa8a52670.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/42637986_135a9786a6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2310126952_7dc86d88f6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1019604187_d087bf9a5f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3640870001_acbd1d5ceb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/307321761_606fc91673.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3578841731_f775cab089.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2592019072_a6c0090da4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/112178718_87270d9b4d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3634281981_d9cf1d1a33.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3613242966_a1c63a0174.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2481598514_05a65d1f72.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3174228611_6cf9d2266b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/263216826_acf868049c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3246804978_ea2c9e56f2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3600909823_ce72c26e66.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2206403470_8c25aa3cf8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2999162229_80d17099b6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/425088533_a460dc4617.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3286111436_891ae7dab9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/174466741_329a52b2fe.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/445148321_9f2f3ac711.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3671777903_6fbf643980.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/241345522_c3c266a02a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2344898759_5674382bcd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3471571540_b4ab77f20d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3342272425_804316cb3d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3484842724_ef1124c87a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2864634088_d087494dff.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2806710650_e201acd913.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2358447641_10f1e9d21f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2933637854_984614e18b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3332248667_617606714b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3517466790_17c7753a1a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2330536645_2d36b516e1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3157744152_31ace8c9ed.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3072782873_3278f3b3a7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3347798761_5c5260b000.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3150742439_b8a352e1e0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3421177332_a05741cfa4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/226531363_33ac01d931.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/760138567_762d9022d4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/251792066_b5233b3d86.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3349955993_a04aea97d8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3539840291_1c3eed701d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/522486784_978021d537.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2720985888_8f5920e8cf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3442272060_f9155194c2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2707244524_d57120d74a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3525453732_f74a38f111.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2756636539_cc1eacbf4a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2630507245_bea4804288.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3085667865_fa001816be.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2216568822_84c295c3b0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/412056525_191724b058.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3716277216_c04002be81.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3243591844_791cfa62eb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3253060519_55d98c208f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3474912569_7165dc1d06.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/346253487_687150ab04.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2587017287_888c811b5a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/501684722_0f20c4e704.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2394919002_ed7527ff93.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3212625256_685bc4de99.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1396703063_e8c3687afe.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3326086533_23a0a54a8e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2762702644_2aa3bf9680.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3583293892_c96af8cd98.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3372340429_91c4f4af30.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3427540832_c882fded1d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3649224118_abe73c672c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3568065409_1c381aa854.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2319175397_3e586cfaf8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3088074124_481139dc92.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2978810122_183e60ff2d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2581066814_179d28f306.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3589052481_059e5e2c37.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3540155303_08225a4567.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2480832276_fa55480ecb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3325157569_8084ab3293.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/302241178_a582c1b953.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3533394378_1513ec90db.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2606433181_f8f9d38579.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2268115375_69884e958d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3359636318_39267812a0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2853407781_c9fea8eef4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3128856481_86e5df4160.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3264678536_46601d25f0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2165461920_1a4144eb2b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3548191125_514f47e493.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3566111626_9a35a7b2c0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3136674757_57406c305c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2192333873_2a0cbe849d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2943384009_c8cf749181.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2628331789_c7f7d90e5d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2171154778_8189169336.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3259229498_2b5708c0c6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/444481722_690d0cadcf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3353962769_ba48691bc6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3699522388_2333f01f40.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2252299132_14ca6e584b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/464116251_1ac4bc91f8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3247423890_163f00a2cb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2887744223_029f2fd5fe.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/101654506_8eb26cfb60.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3085973779_29f44fbdaa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/370614351_98b8a166b9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2286270205_16038dec5a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3587781729_bd21ce7b11.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/380515798_c2abbf46b0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3421706363_a3e22a4908.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3404906655_bc51c69c1e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1368383637_614646cc4a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2426215757_e008a91fcb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2346401538_f5e8da66fc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2085403342_a17b0654fe.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3277162496_dff7eeb59e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/388386075_9ac3a89ada.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/241374292_11e3198daa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/561179884_8b6b925ef9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3553476195_fb3747d7c1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3516960094_87fb4889de.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3242263536_a436f19257.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3247168324_c45eaf734d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3348208268_6d97d951eb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3421928157_69a325366f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3573202338_f43dd22d28.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2949762776_52ece64d28.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3169591322_d0b6d0cd04.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2907073768_08fd7bdf60.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3337046794_296bd2c7e0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/345284642_77dded0907.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2881087519_ca0aa79b2b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3301021288_95935b7a74.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2269795781_46a296aa21.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/911795495_342bb15b97.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3105691757_817083b0a6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/223299137_b0e81ac145.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2218609886_892dcd6915.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2775744946_1ab5d500a2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/485312202_784508f2a9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/416650559_cd08d3cd96.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3756150099_50882fc029.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3639704469_fe83e1c9b7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/756521713_5d3da56a54.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1332815795_8eea44375e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3556792157_d09d42bef7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2222559267_6fd31e3941.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1436760519_8d6101a0ed.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2398605966_1d0c9e6a20.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3703413486_3c682732a0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3599568766_9e96def0ef.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/392976422_c8d0514bc3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/494921598_af73bda568.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2797188545_aeb26c54c0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2902661518_1513be3ea6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2980348138_91cc6f6d0f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3127888173_9a9a8ac3bd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3551170666_01df31412d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2870194345_0bcbac1aa5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/541063419_a5f3672d59.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3345025842_bc2082a509.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3681056426_fbd6c0c92c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/542317719_ed4dd95dc2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2180356743_b3a3c9a7f6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/256283122_a4ef4a17cb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3126681108_f88128699c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3251234434_d01e25a50a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3248220732_0f173fc197.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/109260218_fca831f933.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3606846822_28c40b933a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3124964754_2e8a98fb09.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3450776690_38605c667d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/489065557_0eb08889cd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2326730558_75c20e5033.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3214381315_b54f5c9be4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2458862292_466a920ee2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2474047296_fd9179d438.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3634400263_c6fcaa48e1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3593222804_c187808ac3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3616808182_fb4eaec778.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/448658518_eec0b648a6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/408748500_e8dc8c0c4f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3456251289_c4ae31d817.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3278189732_f750cb26b7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2208310655_a3d83080c5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3571039224_b34fa2f94c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3162442331_c9711857c6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2551344688_17a12a6948.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3245504245_27931f5ec1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3501936223_6122a13d27.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/534313000_4ad39c7ee0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3207264553_8cd4dcde53.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1962729184_6996e128e7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1122944218_8eb3607403.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3295418287_5d590dac43.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3717531382_e1e05e22c5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2801851082_8c3c480c0f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3677860841_3aa9d8036c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3211289105_e0360a9c7f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1716445442_9cf3528342.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3174431688_ae84778db0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1426014905_da60d72957.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2920305300_a5b1b2329a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3001612175_53567ffb58.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/423066487_07757b2b49.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/105342180_4d4a40b47f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2848266893_9693c66275.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2248487956_2603f55ab9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/232874193_c691df882d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2257798999_d9d1b9a45a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1439282131_3814d6ae04.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3702607829_2b8b3e65ab.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2535746605_8124bf4e4f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2372572028_53b76104a9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/136644885_f7d2bbf546.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3399798295_a452963365.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2822891602_ff61df2ece.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3759492488_592cd78ed1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3326273086_e09e845185.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2299427360_422a3fb8b0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/866841633_05d273b96d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1446053356_a924b4893f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3249891130_b241591e89.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3640104986_5d8c9a9948.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2981372647_2061278c60.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3418504074_083f0bb68d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3380072636_4cd59385fd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2076865206_53918c820c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2192026581_b782d1355a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/96399948_b86c61bfe6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3562169000_6aa7f1043d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3420338549_bd78d35243.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3126724531_f483e1b92a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3211581957_df2f7e2236.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1277185009_06478dd457.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1835511273_790eaae6e6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3101378069_f8caa14c0a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3146232740_df3da0163b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/466956209_2ffcea3941.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2518853257_02f30e282e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/241347760_d44c8d3a01.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3046190891_05c6ecd9b6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3361210233_962d630ec5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2635908229_b9fc90d3fb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2883907436_82bf4a36b8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3192266178_f9bf5d3dba.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2812125355_5e11a76533.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/292780636_72e1968949.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3479423813_517e93a43a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3612538549_2828b45867.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2656039837_f46b29af92.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3424605029_53078d3505.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/472535997_0dbf42b9f3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3651107058_d84d4c3c25.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2114355355_9d7e2d8178.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3005872315_e6771763bd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3168796547_0c14b368f9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/10815824_2997e03d76.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3526018344_450c517a72.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2813033949_e19fa08805.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3222749441_3bdfe088e3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2514612680_b0d2d77099.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3320680380_b0d38b3b4a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2975073156_7543ed326f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2351762979_0941aecced.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2600386812_8790879d9a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/241345905_5826a72da1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3532205154_5674b628ea.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2096771662_984441d20d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1434607942_da5432c28c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3707077198_efd6aa808d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2789238858_14261dd25a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3543294190_0037c59607.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/997338199_7343367d7f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3665549027_d7fb05d157.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/468141298_3154d717e1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/379006645_b9a2886b51.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2458033289_f0616879df.jpg': Read-only file system
# ...
# mv: cannot remove '/kaggle/input/flickr8k/Images/2909609550_070eea49b5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1389323170_d1c81d6b51.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3021318991_fa28e3bca7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/310213587_778fe8fb5b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2466171100_5e60cfcc11.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/693450725_8ad72389e6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3195969533_98f5de0fab.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3359089834_263e529c71.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3606942887_1159d92548.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3401437960_7da856e004.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/299676757_571ee47280.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2120571547_05cd56de85.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3138562460_44227a35cf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/145721498_a27d2db576.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3228960484_9aab98b91a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3217910740_d1d61c08ab.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3277824093_299cbb3138.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2584020755_14e2b3e8fc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2570559405_dc93007f76.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3688839836_ba5e4c24fc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/295258727_eaf75e0887.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3397220683_4aca010f86.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3419197575_aa5b84a9f0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3329793486_afc16663cc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/429205889_ff5a006311.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/299178969_5ca1de8e40.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3029928396_99ac250788.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1427391496_ea512cbe7f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2938747424_64e64784f0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1389264266_8170bc1c54.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/549887636_0ea5ae4739.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2061144717_5b3a1864f0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/642987597_03b21a1437.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/298920219_9a3f80acc5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/260520547_944f9f4c91.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3208074567_ac44aeb3f3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/539493431_744eb1abaa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/875731481_a5a0a09934.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3710353645_8fbfaa4175.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3455920874_6fbec43194.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2303426046_09cfd7bc4e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3673878924_506c9d767b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2431120202_b24fe2333a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3585117340_73e96b6173.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2684489465_32ba1d0344.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2125626631_a4b63af97e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2496236371_61dec88113.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1289142574_2bd6a082dd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/566446626_9793890f95.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3457572788_e1fe4f6480.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1358892595_7a37c45788.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3106782647_b078830a9e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3101796900_59c15e0edc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3222250187_ef610f267e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/743571049_68080e8751.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3415003392_139c0f3586.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/254295381_d98fa049f4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3331190056_09f4ca9fd2.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1490213660_9ea45550cf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3181328245_7c04ce1691.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1417031097_ab656bc4bd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3276895962_c053263d01.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3692836015_d11180727b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3286406057_a1668655af.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/350176185_b8c5591e36.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3491607076_922ec561d9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2279980395_989d48ae72.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3437781040_82b06facb3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1387443857_602ab6f9bf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1248357227_2b4175fc39.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3453284877_8866189055.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3244470342_c08f6bb17e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/330849796_c575c3108a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2687229880_97cfd8148e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2274602044_b3d55df235.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3016726158_4d15b83b06.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2448270671_5e0e391a80.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2188688248_f57a28a5a7.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3430100177_5864bf1e73.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3374223949_90776ba934.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2261962622_e9318a95eb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3208553539_2bf6c6d162.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2647394564_4843800cff.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/698107542_3aa0ba78b4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/437404867_209625774d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2830309113_c79d7be554.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3724113279_99b6e5bf41.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3681324243_b69fa90842.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/236518934_c62a133077.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3038045802_93f2cd5fbc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3234719720_5bb2fc5ffa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3042483842_beb23828b9.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2699426519_228719b1db.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/240583223_e26e17ee96.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2128119486_4407061c40.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2444741900_5cb3ef3e1d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1807169176_7f5226bf5a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/247691240_3881777ab8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/525968880_82623392d1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1406010299_5755339f08.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3530504007_3272c57e21.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3694219419_a7a83d4886.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2256138896_3e24b0b28d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/159712188_d530dd478c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3724150944_fc62e8d5e0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1418266617_b32143275b.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2698614194_b4e6e11dff.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/759015118_4bd3617e60.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1763020597_d4cc8f0f8a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1581822598_0ae23074f1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/406642021_9ec852eccf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/899810584_61e1578d3f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2501742763_b2cb322087.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2934837034_a8ca5b1f50.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3677693858_62f2f3163f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2918880895_e61f74f2f0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3175849727_bf30b892cb.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3704995657_e2e114083d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3339140382_2e49bc324a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2660480624_45f88b3022.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/652542470_60e858da64.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3636543173_15f56515e5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3125158798_0743dae56e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3459492423_c881f12c9f.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3500136982_bf7a85531e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/412101267_7257e6d8c0.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3354883962_170d19bfe4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3549277110_24d4064ccd.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3255732353_fbc487aefc.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3322443827_a04a94bb91.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1579198375_84b18e003a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3330019493_fd36fbc2ea.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3335370208_460fc19bfa.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2774581025_81a3074e2e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3569420080_72fbe84751.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/533713007_bf9f3e25b4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2266142543_b2de18c081.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3074617663_2f2634081d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3249014584_21dd9ddd9d.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3294830188_e46bd9b93c.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3272002857_ace031f564.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3346040664_5b584e6133.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3512033861_a357bb58b6.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/498444334_a680d318a1.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2473791980_805c819bd4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2993167197_e5d0a73530.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3364258732_9942c557e5.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3081363964_d404eccae8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3684562647_28dc325522.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/1287073593_f3d2a62455.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2543679402_9359e1ee4e.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/608257195_6ec6f48e37.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3374384485_751f719be4.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3189941492_a3f4347b1a.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3674565156_14d3b41450.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/272283076_2d4aa1d5cf.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/281419391_522557ce27.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/590445887_4d4fa43923.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/502115726_927dd684d3.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/3025438110_40af7e6a80.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/flickr8k/Images/2623982903_58ec7c5026.jpg': Read-only file system

# %%
kaggle_input_path = "/content/sample_data/Flickr8k" # This path is indicated in the error message

images_dir = os.path.join(kaggle_input_path, "Images")
captions_file = os.path.join(kaggle_input_path, "captions.txt")

num_images = 0
if os.path.exists(images_dir):
    num_images = len([f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])

num_captions = 0
if os.path.exists(captions_file):
    with open(captions_file, 'r', encoding='utf-8') as f:
        # Assuming the first line is a header
        num_captions = sum(1 for line in f) - 1

print(f"Total images: {num_images}")
print(f"Total captions: {num_captions}")
# Out:
# Total images: 8091
# Total captions: 40455

# %%
# --- Configuration for Flickr8k Paths ---
# IMPORTANT: Update these paths to where your Flickr8k dataset is located if they are different
FLICKR8K_IMAGES_DIR_PATH = "/content/sample_data/Flickr8k/Images"
FLICKR8K_TOKEN_FILE_PATH = "/content/sample_data/Flickr8k/captions.txt"

print(f"Using Flickr8k Images Path: {FLICKR8K_IMAGES_DIR_PATH}")
print(f"Using Flickr8k Captions File: {FLICKR8K_TOKEN_FILE_PATH}")
# Out:
# Using Flickr8k Images Path: /content/sample_data/Flickr8k/Images
# Using Flickr8k Captions File: /content/sample_data/Flickr8k/captions.txt

# %%
# Read the Flickr8k captions file
#    Assuming each line is in the format:
#        image_name.jpg, A caption describing the image...
# image,caption
#1000268201_693b08cb0e.jpg,A child in a pink dress is climbing up a set of stairs in an entry way .
#    Use names=['image','caption'] since there is no header row.
df = pd.read_csv(
    FLICKR8K_TOKEN_FILE_PATH,
    sep=",",
    names=["image", "caption"],
    header=None,
    engine="python",
)

# 2. Strip any leading/trailing whitespace from caption text
df["caption"] = df["caption"].str.strip()

# 3. Assign a caption_number to each caption (0–4) per image.
#    This assumes that each image appears exactly 5 times, in sequence.
#    If your file isn’t guaranteed to be grouped by image, you can still use groupby().
df["caption_number"] = df.groupby("image").cumcount()

# 4. Create an integer ID for each image.
#    factorize() assigns a unique integer ID (0, 1, 2, …) to each distinct image filename.
df["id"] = df["image"].factorize()[0]

# 5. Reorder columns if you want them in the same order as your original snippet:
df = df[["image", "caption_number", "caption", "id"]]

# 6. Save to CSV
# Save to a new CSV (in the current directory)
PROCESSED_CAPTIONS_CSV_PATH = "/content/sample_data/Flickr8k/flickr8k_captions.csv"
df.to_csv(PROCESSED_CAPTIONS_CSV_PATH, index=False)

# %%
# 7. Peek at the first few rows

print("\nProcessed Flickr8k DataFrame head:")
print(df.head())
print(f"Processed captions saved to: {os.path.abspath(PROCESSED_CAPTIONS_CSV_PATH)}")
# Out:
# Processed Flickr8k DataFrame head:
#                        image  caption_number  \
# 0                      image               0
# 1  1000268201_693b08cb0e.jpg               0
# 2  1000268201_693b08cb0e.jpg               1
# 3  1000268201_693b08cb0e.jpg               2
# 4  1000268201_693b08cb0e.jpg               3
#
#                                              caption  id
# 0                                            caption   0
# 1  A child in a pink dress is climbing up a set o...   1
# 2              A girl going into a wooden building .   1
# 3   A little girl climbing into a wooden playhouse .   1
# 4  A little girl climbing the stairs to her playh...   1
# Processed captions saved to: /content/sample_data/Flickr8k/flickr8k_captions.csv

# %% [markdown]
# ### Block 2: CFG, Utility Classes, and Dataset Class

# %%
class CFG:
    debug = False # Set to True for smaller dataset runs and fewer epochs
    image_path = FLICKR8K_IMAGES_DIR_PATH # From Block 1
    captions_path = "." # Directory where processed_captions_file is saved
    processed_captions_file = PROCESSED_CAPTIONS_CSV_PATH # From Block 1

    batch_size = 32
    num_workers = 2 # Adjust based on your environment (0 often safest for notebooks)
    head_lr = 1e-3
    image_encoder_lr = 1e-4
    text_encoder_lr = 1e-5
    weight_decay = 1e-3 # For projection heads in optimizer setup
    patience = 2 # For ReduceLROnPlateau
    factor = 0.5 # For ReduceLROnPlateau
    #epochs = 3 if debug else 10 # Reduced for faster runs, adjust as needed

    # --- Parameters for Training Optimization ---
    epochs = 10 if not debug else 5 # Increase epochs to allow early stopping to find the best one
    gradient_accumulation_steps = 2 # Set to 1 to disable, >1 to enable. Effective batch size = batch_size * this value
    early_stopping_patience = 3 # Stop training if valid_loss doesn't improve for this many epochs


    # --- Parameters for New LR Scheduler ---
    warmup_epochs = 2 # Number of epochs for linear warmup
    lr_min = 1e-6 # Minimum learning rate for cosine annealing

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model_name = 'resnet50'
    image_embedding = 2048 # Output dim of ResNet50 before projection
    text_encoder_model = "distilbert-base-uncased"
    text_embedding = 768   # Output dim of DistilBert before projection
    text_tokenizer = "distilbert-base-uncased" # Tokenizer model name
    max_length = 200 # Max sequence length for captions

    pretrained = True # Use pretrained weights for image and text encoders
    trainable = True # Fine-tune image and text encoders
    temperature = 1.0 # Initial value for temperature (used as fixed in this CLIPModel)

    size = 224 # Image size

    num_projection_layers = 1 # Informational, as ProjectionHead structure is fixed
    projection_dim = 256 # Dimension of the joint embedding space
    dropout = 0.1

cfg = CFG() # Create an instance of the configuration

# %%
#UTILS
class AvgMeter:
    def __init__(self, name="Metric"):
        self.name = name
        self.reset()

    def reset(self):
        self.avg, self.sum, self.count = [0] * 3

    def update(self, val, count=1):
        self.count += count
        self.sum += val * count
        if self.count > 0:
            self.avg = self.sum / self.count
        else:
            self.avg = 0


    def __repr__(self):
        text = f"{self.name}: {self.avg:.4f}"
        return text

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group["lr"] # Returns the LR of the first param group

# %%
class CLIPDataset(torch.utils.data.Dataset):
    def __init__(self, image_filenames, captions, tokenizer, transforms):
        self.image_filenames = image_filenames
        self.captions = list(captions)
        self.encoded_captions = tokenizer(
            self.captions, padding=True, truncation=True, max_length=cfg.max_length
        )
        self.transforms = transforms

    def __getitem__(self, idx):
        item = {
            key: torch.tensor(values[idx])
            for key, values in self.encoded_captions.items()
        }
        image_file_path = os.path.join(cfg.image_path, self.image_filenames[idx])
        try:
            image = cv2.imread(image_file_path)
            if image is None:
                # print(f"Warning: Failed to read image {image_file_path} at index {idx}. Using placeholder.")
                image = np.zeros((cfg.size, cfg.size, 3), dtype=np.uint8) # Placeholder

            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            transformed = self.transforms(image=image)
            image_tensor = transformed['image']

            if not isinstance(image_tensor, torch.Tensor):
                 image_tensor = torch.from_numpy(image_tensor)

            if image_tensor.ndim == 3 and image_tensor.shape[0] != 3 and image_tensor.shape[2] in [1, 3, 4]: # HWC check (common if ToTensorV2 not last)
                image_tensor = image_tensor.permute(2, 0, 1)

            item['image'] = image_tensor.float()
            item['caption_text'] = self.captions[idx]
        except Exception as e:
            print(f"Error processing item {idx}, image {image_file_path}: {e}")
            item['image'] = torch.zeros((3, cfg.size, cfg.size)).float() # Fallback image
            item['caption_text'] = "error placeholder caption"
             # Ensure tokenized keys still exist even if error
            if 'input_ids' not in item:
                 temp_tokenizer = DistilBertTokenizer.from_pretrained(cfg.text_tokenizer)
                 dummy_tokens = temp_tokenizer(item['caption_text'],padding="max_length",truncation=True,max_length=cfg.max_length, return_tensors="pt")
                 item.update({key: values[0] for key, values in dummy_tokens.items()})
        return item

    def __len__(self):
        return len(self.captions)

# %%
# Replace your old get_transforms function with this one

def get_transforms(mode="train"):
    """
    Returns a set of Albumentations transformations based on the mode.
    """
    if mode == "train":
        # Augmentations for the training set
        return A.Compose(
            [
                # FIX: Use the 'size' parameter with a tuple, as required by your albumentations version.
                # This is the primary fix for the error you are seeing.
                A.RandomResizedCrop(size=(cfg.size, cfg.size), scale=(0.8, 1.0), ratio=(0.75, 1.333), always_apply=True),

                A.HorizontalFlip(p=0.5),
                A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.3),
                A.RandomBrightnessContrast(p=0.3),
                A.GaussianBlur(p=0.1),
                A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, always_apply=True),
            ]
        )
    else:
        # "valid" or "test" mode: only resize and normalize
        return A.Compose(
            [
                # FIX: Use explicit height and width for Resize, as its API is more stable and standard.
                # If this also fails, change it to size=(cfg.size, cfg.size) as well.
                A.Resize(height=cfg.size, width=cfg.size, always_apply=True),

                A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, always_apply=True),
            ]
        )

# %% [markdown]
# ### Block 3: Model Architecture and Loss Function

# %%
class ImageEncoder(nn.Module):
    def __init__(
        self, model_name=cfg.model_name, pretrained=cfg.pretrained, trainable=cfg.trainable
    ):
        super().__init__()
        self.model = timm.create_model(
            model_name, pretrained=pretrained, num_classes=0, global_pool="avg"
        )
        for p in self.model.parameters():
            p.requires_grad = trainable

    def forward(self, x):
        return self.model(x)

# %%
class TextEncoder(nn.Module):
    def __init__(self, model_name=cfg.text_encoder_model, pretrained=cfg.pretrained, trainable=cfg.trainable):
        super().__init__()
        if pretrained:
            self.model = DistilBertModel.from_pretrained(model_name)
        else:
            # For non-pretrained, still use the config of the specified model to match dimensions etc.
            config = DistilBertConfig.from_pretrained(model_name)
            self.model = DistilBertModel(config=config)

        for p in self.model.parameters():
            p.requires_grad = trainable
        self.target_token_idx = 0 # Index of CLS token

    def forward(self, input_ids, attention_mask):
        output = self.model(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = output.last_hidden_state
        return last_hidden_state[:, self.target_token_idx, :] # CLS token embedding

# %%
class ProjectionHead(nn.Module):
    def __init__(
        self,
        embedding_dim, # Input embedding dimension from the encoder
        projection_dim=cfg.projection_dim, # Output dimension (joint embedding space)
        dropout=cfg.dropout
    ):
        super().__init__()
        self.projection = nn.Linear(embedding_dim, projection_dim)
        self.gelu = nn.GELU()
        self.fc = nn.Linear(projection_dim, projection_dim)
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(projection_dim)

    def forward(self, x):
        projected = self.projection(x)
        x_gelu = self.gelu(projected)
        x_fc = self.fc(x_gelu)
        x_dropout = self.dropout(x_fc)
        x_residual = x_dropout + projected # Residual connection
        x_norm = self.layer_norm(x_residual)
        return x_norm

# %%
class CLIPModel(nn.Module):
    def __init__(
        self,
        # temperature parameter is removed from __init__ args
        image_embedding_dim=cfg.image_embedding,
        text_embedding_dim=cfg.text_embedding,
    ):
        super().__init__()
        self.image_encoder = ImageEncoder()
        self.text_encoder = TextEncoder()
        self.image_projection = ProjectionHead(embedding_dim=image_embedding_dim)
        self.text_projection = ProjectionHead(embedding_dim=text_embedding_dim)

        # CHANGE 1: Implement a learnable temperature parameter (logit_scale)
        # This parameter will be learned during training.
        # The initial value is taken from the original CLIP paper.
        self.logit_scale = nn.Parameter(torch.ones([]) * np.log(1 / 0.07))

    def encode_image(self, image_tensor):
        image_features = self.image_encoder(image_tensor)
        image_embeddings = self.image_projection(image_features)
        return F.normalize(image_embeddings, p=2, dim=-1)

    def encode_text(self, input_ids, attention_mask):
        text_features = self.text_encoder(input_ids=input_ids, attention_mask=attention_mask)
        text_embeddings = self.text_projection(text_features)
        return F.normalize(text_embeddings, p=2, dim=-1)

    def forward(self, batch):
        image_embeddings = self.encode_image(batch["image"])
        text_embeddings = self.encode_text(
            input_ids=batch["input_ids"], attention_mask=batch["attention_mask"]
        )

        # CHANGE 2: Implement the standard InfoNCE Loss

        # Get the learnable temperature
        logit_scale = self.logit_scale.exp()

        # Calculate cosine similarity scores (logits)
        # The dot product of normalized embeddings is the cosine similarity
        logits_per_image = image_embeddings @ text_embeddings.T * logit_scale
        # For symmetry, we can just transpose the above matrix
        logits_per_text = logits_per_image.T

        # Create the ground-truth labels. For a batch of N pairs, the correct
        # text for image `i` is at index `i` (and vice-versa).
        batch_size = image_embeddings.shape[0]
        labels = torch.arange(batch_size, device=logits_per_image.device)

        # Calculate cross-entropy loss for both directions (image-to-text and text-to-image)
        # We use the built-in, highly optimized F.cross_entropy
        loss_img = F.cross_entropy(logits_per_image, labels)
        loss_txt = F.cross_entropy(logits_per_text, labels)

        # Average the two losses
        loss = (loss_img + loss_txt) / 2.0

        return loss

# %%
print("\nModel architecture classes (ImageEncoder, TextEncoder, ProjectionHead, CLIPModel) and loss function defined.")
# Out:
# Model architecture classes (ImageEncoder, TextEncoder, ProjectionHead, CLIPModel) and loss function defined.

# %% [markdown]
# ### Block 4: Training Loop and Data Loaders Setup

# %%
def make_train_valid_dfs():
    captions_file_to_read = os.path.join(cfg.captions_path, cfg.processed_captions_file)
    print(f"Reading captions for train/valid split from: {captions_file_to_read}")
    try:
        dataframe = pd.read_csv(captions_file_to_read)
        if dataframe.empty:
            print("Error: Loaded dataframe for splitting is empty.")
            return pd.DataFrame(), pd.DataFrame()
    except FileNotFoundError:
        print(f"Error: Processed captions file not found at {captions_file_to_read}. Cannot create train/valid splits.")
        return pd.DataFrame(), pd.DataFrame()

    if "id" not in dataframe.columns or dataframe["id"].isnull().all():
        print("Error: 'id' column is missing or all null in the dataframe. Cannot split data by image ID.")
        return pd.DataFrame(), pd.DataFrame()

    valid_id_values = dataframe["id"].dropna().astype(int)
    if valid_id_values.empty:
        print("Error: No valid 'id' values found for splitting.")
        return pd.DataFrame(), pd.DataFrame()

    unique_image_ids_in_df = sorted(valid_id_values.unique())

    if cfg.debug:
        debug_max_unique_ids = min(20, len(unique_image_ids_in_df)) # e.g., 20 unique images for debug
        image_ids_to_split = unique_image_ids_in_df[:debug_max_unique_ids]
        print(f"Debug mode: Using {len(image_ids_to_split)} unique image IDs for train/valid split.")
    else:
        image_ids_to_split = unique_image_ids_in_df

    if not image_ids_to_split: # Check if list is empty
        print("No image IDs available for splitting after filtering (or in debug mode).")
        return pd.DataFrame(), pd.DataFrame()

    np.random.seed(42)
    num_valid_samples = int(0.2 * len(image_ids_to_split))
    if len(image_ids_to_split) > 0 and num_valid_samples == 0 : # Ensure at least 1 validation ID if possible
        num_valid_samples = 1
    if num_valid_samples > len(image_ids_to_split): # If 0.2*len is > len (only if len<5)
        num_valid_samples = max(0, len(image_ids_to_split) -1 ) # Ensure at least 1 train ID if possible


    valid_image_ids = np.random.choice(
        image_ids_to_split, size=num_valid_samples, replace=False
    )
    train_image_ids = [id_ for id_ in image_ids_to_split if id_ not in valid_image_ids]

    train_dataframe = dataframe[dataframe["id"].isin(train_image_ids)].reset_index(drop=True)
    valid_dataframe = dataframe[dataframe["id"].isin(valid_image_ids)].reset_index(drop=True)

    print(f"Train DataFrame shape: {train_dataframe.shape} ({len(train_image_ids)} unique images)")
    print(f"Valid DataFrame shape: {valid_dataframe.shape} ({len(valid_image_ids)} unique images)")
    return train_dataframe, valid_dataframe

# %%
def build_loaders(dataframe, tokenizer, mode):
    if dataframe.empty or not all(col in dataframe.columns for col in ["image", "caption"]):
        print(f"Warning: DataFrame for mode '{mode}' is empty or missing key columns. Returning None for DataLoader.")
        return None

    transforms = get_transforms(mode=mode) # mode is "train" or "valid"/"test"
    dataset = CLIPDataset(
        dataframe["image"].values,
        dataframe["caption"].values,
        tokenizer=tokenizer,
        transforms=transforms,
    )

    if len(dataset) == 0:
        print(f"Warning: Dataset for mode '{mode}' is empty after initialization. Returning None for DataLoader.")
        return None

    dataloader = torch.utils.data.DataLoader(
        dataset,
        batch_size=cfg.batch_size,
        num_workers=cfg.num_workers,
        shuffle=True if mode == "train" else False,
        pin_memory=True if cfg.device == "cuda" else False
    )
    return dataloader

# %%
def train_epoch(model, train_loader, optimizer, lr_scheduler, scheduler_step_mode):
    loss_meter = AvgMeter()
    model.train()
    tqdm_object = tqdm(train_loader, total=len(train_loader), desc="Training Epoch")

    # Reset gradients at the start of the epoch
    optimizer.zero_grad()

    for i, batch in enumerate(tqdm_object):
        batch_on_device = {}
        for k, v in batch.items():
            if isinstance(v, torch.Tensor):
                batch_on_device[k] = v.to(cfg.device)

        loss = model(batch_on_device)

        # Scale loss by accumulation steps to average the loss over the accumulated batches
        loss = loss / cfg.gradient_accumulation_steps

        # Accumulate gradients
        loss.backward()

        # Step the optimizer and scheduler only after accumulating enough gradients
        if (i + 1) % cfg.gradient_accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad() # Reset gradients for the next accumulation cycle

            if scheduler_step_mode == "batch":
                if lr_scheduler is not None:
                    lr_scheduler.step()

        count = batch_on_device["image"].size(0)
        # We use loss.item() * accumulation_steps to log the "un-scaled" loss for readability
        loss_meter.update(loss.item() * cfg.gradient_accumulation_steps, count)

        tqdm_object.set_postfix(train_loss=loss_meter.avg, lr=get_lr(optimizer))

    return loss_meter

def valid_epoch(model, valid_loader):
    loss_meter = AvgMeter()
    model.eval() # Ensure model is in evaluation mode
    tqdm_object = tqdm(valid_loader, total=len(valid_loader), desc=f"Validation Epoch")
    with torch.no_grad(): # No gradients needed for validation
        for batch in tqdm_object:
            batch_on_device = {}
            for k, v in batch.items():
                if isinstance(v, torch.Tensor):
                    batch_on_device[k] = v.to(cfg.device)

            loss = model(batch_on_device)

            count = batch_on_device["image"].size(0)
            loss_meter.update(loss.item(), count)
            tqdm_object.set_postfix(valid_loss=loss_meter.avg)
    return loss_meter

# %%
# --- Main Training Script Execution ---
print("\n--- Starting CLIP Model Training Process ---")

# 1. Create train and valid DataFrames
# `df` (the full dataframe) should be available from Block 1
if 'df' not in locals() or df.empty:
    print("Base DataFrame 'df' is not available or empty. Halting.")
else:
    train_df, valid_df = make_train_valid_dfs()

    if train_df.empty or valid_df.empty:
        print("Train or Valid DataFrame is empty after split. Halting training.")
    else:
        # 2. Initialize Tokenizer
        tokenizer = DistilBertTokenizer.from_pretrained(cfg.text_tokenizer)
        print("Tokenizer initialized.")

        # 3. Build DataLoaders
        train_loader = build_loaders(train_df, tokenizer, mode="train")
        valid_loader = build_loaders(valid_df, tokenizer, mode="valid")

        if train_loader is None or valid_loader is None:
            print("Failed to build DataLoaders. Halting training.")
        else:
            print("DataLoaders built successfully.")
            # 4. Initialize Model
            model = CLIPModel().to(cfg.device)
            print(f"CLIPModel initialized on {cfg.device}.")

            # 5. Setup Optimizer
            params = [
                {"params": model.image_encoder.parameters(), "lr": cfg.image_encoder_lr, "weight_decay": 0.0},
                {"params": model.text_encoder.parameters(), "lr": cfg.text_encoder_lr, "weight_decay": 0.0},
                {"params": itertools.chain(
                    model.image_projection.parameters(), model.text_projection.parameters()
                ), "lr": cfg.head_lr, "weight_decay": cfg.weight_decay}
            ]
            optimizer = torch.optim.AdamW(params)
            print("Optimizer AdamW initialized.")

            # 6. Setup NEW LR Scheduler: Cosine Annealing with Warmup
            # We need to import the scheduler from transformers
            from transformers import get_cosine_schedule_with_warmup

            num_training_steps = len(train_loader) * cfg.epochs
            num_warmup_steps = len(train_loader) * cfg.warmup_epochs

            lr_scheduler = get_cosine_schedule_with_warmup(
                optimizer,
                num_warmup_steps=num_warmup_steps,
                num_training_steps=num_training_steps
            )
            # Note: A more complex scheduler could also apply min_lr, but this is a solid standard.

            print("LR Scheduler (CosineAnnealingWithWarmup) initialized.")

            # The new scheduler steps after every BATCH
            scheduler_step_mode = "batch"

            best_loss = float('inf')
            best_epoch = -1

            # 7. Training Loop
            for epoch in range(cfg.epochs):
                print(f"\nEpoch: {epoch + 1}/{cfg.epochs}")

                # Pass the new scheduler and step mode to the training function
                train_loss_meter = train_epoch(model, train_loader, optimizer, lr_scheduler, scheduler_step_mode)
                print(f"Epoch {epoch+1} Train Loss: {train_loss_meter.avg:.4f}, LR: {get_lr(optimizer):.1e}")

                valid_loss_meter = valid_epoch(model, valid_loader)
                print(f"Epoch {epoch+1} Valid Loss: {valid_loss_meter.avg:.4f}")

                if valid_loss_meter.avg < best_loss:
                    best_loss = valid_loss_meter.avg
                    best_epoch = epoch + 1
                    torch.save({
                        'epoch': epoch + 1,
                        'model_state_dict': model.state_dict(),
                        'optimizer_state_dict': optimizer.state_dict(),
                        'best_loss': best_loss,
                        'cfg': vars(cfg)
                        }, "/content/sample_data/Flickr8k/best_model_checkpoint.pt")
                    print(f"Saved Best Model at Epoch {epoch+1}! Validation Loss: {best_loss:.4f}")

                # The old lr_scheduler.step(valid_loss_meter.avg) is no longer needed here
                # because the new scheduler steps with the optimizer inside train_epoch.

            print("\n--- Training Complete ---")
            print(f"Best Validation Loss: {best_loss:.4f} achieved at Epoch {best_epoch}")
            print(f"Best model saved to: best_model_checkpoint.pt")
# Out:
# --- Starting CLIP Model Training Process ---
# Reading captions for train/valid split from: /content/sample_data/Flickr8k/flickr8k_captions.csv
# Train DataFrame shape: (32366, 4) (6474 unique images)
# Valid DataFrame shape: (8090, 4) (1618 unique images)
# Tokenizer initialized.
# <ipython-input-16-bdca82284c5d>:13: UserWarning: Argument(s) 'always_apply' are not valid for transform RandomResizedCrop
#   A.RandomResizedCrop(size=(cfg.size, cfg.size), scale=(0.8, 1.0), ratio=(0.75, 1.333), always_apply=True),
# <ipython-input-16-bdca82284c5d>:19: UserWarning: Argument(s) 'always_apply' are not valid for transform Normalize
#   A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, always_apply=True),
# <ipython-input-16-bdca82284c5d>:28: UserWarning: Argument(s) 'always_apply' are not valid for transform Resize
#   A.Resize(height=cfg.size, width=cfg.size, always_apply=True),
# <ipython-input-16-bdca82284c5d>:30: UserWarning: Argument(s) 'always_apply' are not valid for transform Normalize
#   A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, always_apply=True),
# DataLoaders built successfully.
# CLIPModel initialized on cuda.
# Optimizer AdamW initialized.
# LR Scheduler (CosineAnnealingWithWarmup) initialized.
#
# Epoch: 1/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 1 Train Loss: 2.0509, LR: 2.5e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 1 Valid Loss: 2.1014
# Saved Best Model at Epoch 1! Validation Loss: 2.1014
#
# Epoch: 2/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 2 Train Loss: 0.9181, LR: 5.0e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 2 Valid Loss: 2.0386
# Saved Best Model at Epoch 2! Validation Loss: 2.0386
#
# Epoch: 3/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 3 Train Loss: 0.6222, LR: 7.5e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 3 Valid Loss: 1.9991
# Saved Best Model at Epoch 3! Validation Loss: 1.9991
#
# Epoch: 4/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 4 Train Loss: 0.4648, LR: 1.0e-04
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 4 Valid Loss: 1.9627
# Saved Best Model at Epoch 4! Validation Loss: 1.9627
#
# Epoch: 5/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 5 Train Loss: 0.3574, LR: 9.9e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 5 Valid Loss: 1.9593
# Saved Best Model at Epoch 5! Validation Loss: 1.9593
#
# Epoch: 6/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 6 Train Loss: 0.2816, LR: 9.6e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 6 Valid Loss: 1.9524
# Saved Best Model at Epoch 6! Validation Loss: 1.9524
#
# Epoch: 7/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 7 Train Loss: 0.2392, LR: 9.2e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 7 Valid Loss: 1.9605
#
# Epoch: 8/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 8 Train Loss: 0.2045, LR: 8.5e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 8 Valid Loss: 1.9483
# Saved Best Model at Epoch 8! Validation Loss: 1.9483
#
# Epoch: 9/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 9 Train Loss: 0.1800, LR: 7.8e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 9 Valid Loss: 1.9557
#
# Epoch: 10/10
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 10 Train Loss: 0.1621, LR: 6.9e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 10 Valid Loss: 1.9547
#
# --- Training Complete ---
# Best Validation Loss: 1.9483 achieved at Epoch 8
# Best model saved to: best_model_checkpoint.pt

# %%
# In Block 4, replace the final training loop execution block with this one

# ... (ensure model, optimizer, loaders etc. are initialized before this)

"""if 'train_loader' in locals() and 'valid_loader' in locals() and train_loader is not None and valid_loader is not None:
    best_loss = float('inf')
    best_epoch = -1
    epochs_without_improvement = 0

    # Training Loop with Early Stopping
    for epoch in range(cfg.epochs):
        print(f"\nEpoch: {epoch + 1}/{cfg.epochs}")

        train_loss_meter = train_epoch(model, train_loader, optimizer, lr_scheduler, scheduler_step_mode)
        print(f"Epoch {epoch+1} Train Loss: {train_loss_meter.avg:.4f}, LR: {get_lr(optimizer):.1e}")

        valid_loss_meter = valid_epoch(model, valid_loader)
        print(f"Epoch {epoch+1} Valid Loss: {valid_loss_meter.avg:.4f}")

        # Check for improvement
        if valid_loss_meter.avg < best_loss:
            best_loss = valid_loss_meter.avg
            best_epoch = epoch + 1
            epochs_without_improvement = 0 # Reset counter
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_loss': best_loss,
                'cfg': vars(cfg)
                }, "best_model_checkpoint.pt")
            print(f"Saved Best Model! Validation Loss: {best_loss:.4f}")
        else:
            epochs_without_improvement += 1
            print(f"No improvement in validation loss for {epochs_without_improvement} epoch(s).")

        # Early stopping condition
        if epochs_without_improvement >= cfg.early_stopping_patience:
            print(f"\nEarly stopping triggered after {cfg.early_stopping_patience} epochs without improvement.")
            break

        if scheduler_step_mode == "epoch":
            lr_scheduler.step(valid_loss_meter.avg)

    print("\n--- Training Complete ---")
    if best_epoch != -1:
        print(f"Best Validation Loss: {best_loss:.4f} achieved at Epoch {best_epoch}")
        print(f"Best model saved to: best_model_checkpoint.pt")
    else:
        print("Training finished without any model being saved as 'best'.")
else:
    print("Skipping training loop because DataLoaders were not created successfully.")"""
# Out:
# Epoch: 1/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 1 Train Loss: 2.0500, LR: 2.5e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 1 Valid Loss: 2.1033
# Saved Best Model! Validation Loss: 2.1033
#
# Epoch: 2/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 2 Train Loss: 0.9122, LR: 5.0e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 2 Valid Loss: 2.0278
# Saved Best Model! Validation Loss: 2.0278
#
# Epoch: 3/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 3 Train Loss: 0.6263, LR: 7.5e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 3 Valid Loss: 1.9862
# Saved Best Model! Validation Loss: 1.9862
#
# Epoch: 4/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 4 Train Loss: 0.4682, LR: 1.0e-04
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 4 Valid Loss: 1.9639
# Saved Best Model! Validation Loss: 1.9639
#
# Epoch: 5/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 5 Train Loss: 0.3609, LR: 1.0e-04
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 5 Valid Loss: 1.9559
# Saved Best Model! Validation Loss: 1.9559
#
# Epoch: 6/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 6 Train Loss: 0.2892, LR: 9.9e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 6 Valid Loss: 1.9631
# No improvement in validation loss for 1 epoch(s).
#
# Epoch: 7/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 7 Train Loss: 0.2404, LR: 9.8e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 7 Valid Loss: 1.9519
# Saved Best Model! Validation Loss: 1.9519
#
# Epoch: 8/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 8 Train Loss: 0.2071, LR: 9.7e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 8 Valid Loss: 1.9474
# Saved Best Model! Validation Loss: 1.9474
#
# Epoch: 9/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 9 Train Loss: 0.1850, LR: 9.5e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 9 Valid Loss: 1.9570
# No improvement in validation loss for 1 epoch(s).
#
# Epoch: 10/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 10 Train Loss: 0.1650, LR: 9.3e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 10 Valid Loss: 1.9550
# No improvement in validation loss for 2 epoch(s).
#
# Epoch: 11/20
# Training Epoch:   0%|          | 0/1012 [00:00<?, ?it/s]
# Epoch 11 Train Loss: 0.1491, LR: 9.1e-05
# Validation Epoch:   0%|          | 0/253 [00:00<?, ?it/s]
# Epoch 11 Valid Loss: 1.9576
# No improvement in validation loss for 3 epoch(s).
#
# Early stopping triggered after 3 epochs without improvement.
#
# --- Training Complete ---
# Best Validation Loss: 1.9474 achieved at Epoch 8
# Best model saved to: best_model_checkpoint.pt

# %%
# !mv ./best_model_checkpoint.pt /content/sample_data/Flickr8k/.

# %% [markdown]
# ### Block 5: Embedding Generation (After Training)

# %%
print("\n--- Preparing for Embedding Generation (Post-Training) ---")

MODEL_CHECKPOINT_PATH = "/content/sample_data/Flickr8k/best_model_checkpoint.pt" # Path to the saved best model

# Ensure CFG and CLIPModel class are defined from previous blocks
# cfg instance should already be defined

if os.path.exists(MODEL_CHECKPOINT_PATH):
    loaded_model_for_embedding = CLIPModel().to(cfg.device)
    try:
        checkpoint = torch.load(MODEL_CHECKPOINT_PATH, map_location=cfg.device)
        loaded_model_for_embedding.load_state_dict(checkpoint['model_state_dict'])
        print(f"Model loaded successfully for embedding generation from {MODEL_CHECKPOINT_PATH}")
        loaded_model_for_embedding.eval()
    except Exception as e:
        print(f"Error loading model from {MODEL_CHECKPOINT_PATH}: {e}. Cannot generate embeddings.")
        loaded_model_for_embedding = None # Ensure it's None if loading failed
else:
    print(f"Model checkpoint {MODEL_CHECKPOINT_PATH} not found. Cannot generate embeddings.")
    loaded_model_for_embedding = None
# Out:
# --- Preparing for Embedding Generation (Post-Training) ---
# Model loaded successfully for embedding generation from /content/sample_data/Flickr8k/best_model_checkpoint.pt

# %%
if loaded_model_for_embedding:
    # Initialize tokenizer and image transforms
    tokenizer_for_embedding = DistilBertTokenizer.from_pretrained(cfg.text_tokenizer)
    image_transforms_for_embedding = get_transforms(mode="valid")

    # Prepare the DataFrame for which you want to generate embeddings.
    # Example: using the 'valid_df' created during training.
    # Or, load the full 'df' if you want embeddings for the entire dataset.
    # For consistency, let's use the 'valid_df' that was defined during the training block, if available.
    # If not, we re-create it.

    if 'valid_df' not in locals() or valid_df.empty:
        print("`valid_df` not in scope or empty from training. Re-creating a validation split for embedding example.")
        if 'df' not in locals() or df.empty:
             print("Base DataFrame 'df' not found or empty. Reloading processed captions...")
             try:
                 df = pd.read_csv(os.path.join(cfg.captions_path, cfg.processed_captions_file))
                 if df.empty: raise ValueError("Reloaded DataFrame for splitting is empty.")
             except Exception as e_reload:
                 print(f"Could not load base DataFrame: {e_reload}")
                 df = pd.DataFrame() # empty df

        if not df.empty:
            _, current_target_df_for_embeddings = make_train_valid_dfs() # This gets a new split
            # Ideally, for evaluating the *trained* model, you'd use the exact same valid_df from training.
            # If `valid_df` from the training block is still in scope, prefer using that.
            # This re-split is for a self-contained example here.
            print(f"Using a new validation split (shape: {current_target_df_for_embeddings.shape}) for embedding generation.")
        else:
            print("Base DataFrame 'df' is empty. Cannot generate splits for embedding example.")
            current_target_df_for_embeddings = pd.DataFrame()
    else:
        print("Using `valid_df` from the training phase for embedding generation.")
        current_target_df_for_embeddings = valid_df # Use the one from the training block

    if not current_target_df_for_embeddings.empty:
        print(f"Target DataFrame for embeddings (shape: {current_target_df_for_embeddings.shape})")

        def generate_image_embeddings_dict(dataframe, image_column_name, model_to_use, transforms, cfg_obj_ref):
            if dataframe.empty or image_column_name not in dataframe.columns:
                print(f"Warning: DataFrame empty or missing '{image_column_name}'. Returning empty dict for image embeddings.")
                return {}
            unique_image_filenames = sorted(list(dataframe[image_column_name].unique()))
            image_embeddings_map = {}
            model_to_use.eval() # Ensure model is in eval mode
            print(f"Generating embeddings for {len(unique_image_filenames)} unique images...")
            with torch.no_grad():
                for image_filename in tqdm(unique_image_filenames, desc="Generating Image Embeddings"):
                    image_path = os.path.join(cfg_obj_ref.image_path, image_filename)
                    try:
                        image = cv2.imread(image_path)
                        if image is None: continue
                        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                        transformed = transforms(image=image)
                        img_tensor = transformed['image']
                        if not isinstance(img_tensor, torch.Tensor): img_tensor = torch.from_numpy(img_tensor)
                        if img_tensor.ndim == 3 and img_tensor.shape[0] != 3: img_tensor = img_tensor.permute(2, 0, 1)
                        img_tensor = img_tensor.unsqueeze(0).float().to(cfg_obj_ref.device)
                        embedding = model_to_use.encode_image(img_tensor)
                        image_embeddings_map[image_filename] = embedding.squeeze(0).cpu()
                    except Exception as e_img: print(f"Error for image {image_path}: {e_img}")
            return image_embeddings_map

        def generate_text_embeddings_dict(dataframe, img_col, cap_num_col, cap_text_col, model_to_use, tokenizer_ref, cfg_obj_ref):
            if dataframe.empty or not all(c in dataframe.columns for c in [img_col, cap_num_col, cap_text_col]):
                print("Warning: DataFrame empty or missing columns for text embeddings. Returning empty dict.")
                return {}
            text_embeddings_map = {}
            captions_data = []
            for _, row in dataframe.iterrows():
                caption_key = f"{row[img_col]}_cap_{row[cap_num_col]}"
                captions_data.append((caption_key, row[cap_text_col]))
            model_to_use.eval() # Ensure model is in eval mode
            print(f"Generating embeddings for {len(captions_data)} captions...")
            with torch.no_grad():
                for i in tqdm(range(0, len(captions_data), cfg_obj_ref.batch_size), desc="Generating Text Embeddings"):
                    batch_data = captions_data[i:i + cfg_obj_ref.batch_size]
                    batch_keys = [item[0] for item in batch_data]
                    batch_texts = [item[1] for item in batch_data]
                    try:
                        tokens = tokenizer_ref(batch_texts, padding=True, truncation=True, max_length=cfg_obj_ref.max_length, return_tensors="pt")
                        input_ids = tokens["input_ids"].to(cfg_obj_ref.device)
                        attention_mask = tokens["attention_mask"].to(cfg_obj_ref.device)
                        batch_text_embeddings = model_to_use.encode_text(input_ids, attention_mask)
                        for key, embedding in zip(batch_keys, batch_text_embeddings):
                            text_embeddings_map[key] = embedding.cpu()
                    except Exception as e_txt: print(f"Error for text batch starting with {batch_keys[0] if batch_keys else 'N/A'}: {e_txt}")
            return text_embeddings_map

        # Generate embeddings
        generated_image_embeddings = generate_image_embeddings_dict(
            dataframe=current_target_df_for_embeddings,
            image_column_name='image',
            model_to_use=loaded_model_for_embedding,
            transforms=image_transforms_for_embedding,
            cfg_obj_ref=cfg
        )
        print(f"Generated {len(generated_image_embeddings)} unique image embeddings.")

        generated_text_embeddings = generate_text_embeddings_dict(
            dataframe=current_target_df_for_embeddings,
            img_col='image',
            cap_num_col='caption_number',
            cap_text_col='caption',
            model_to_use=loaded_model_for_embedding,
            tokenizer_ref=tokenizer_for_embedding,
            cfg_obj_ref=cfg
        )
        print(f"Generated {len(generated_text_embeddings)} text embeddings.")

        # Save these embeddings for the next step
        EMBEDDINGS_OUTPUT_DIR = "/content/sample_data/Flickr8k/final_embeddings/"
        os.makedirs(EMBEDDINGS_OUTPUT_DIR, exist_ok=True)
        IMG_EMB_PATH = os.path.join(EMBEDDINGS_OUTPUT_DIR, "final_image_embeddings.pt")
        TXT_EMB_PATH = os.path.join(EMBEDDINGS_OUTPUT_DIR, "final_text_embeddings.pt")

        if generated_image_embeddings:
            torch.save(generated_image_embeddings, IMG_EMB_PATH)
            print(f"Image embeddings saved to {IMG_EMB_PATH}")
        if generated_text_embeddings:
            torch.save(generated_text_embeddings, TXT_EMB_PATH)
            print(f"Text embeddings saved to {TXT_EMB_PATH}")
    else:
        print("Target DataFrame for embeddings is empty. Skipping embedding generation.")
else:
    print("Skipping embedding generation as trained model could not be loaded.")
# Out:
# Using `valid_df` from the training phase for embedding generation.
# Target DataFrame for embeddings (shape: (8090, 4))
# Generating embeddings for 1618 unique images...
# <ipython-input-16-bdca82284c5d>:28: UserWarning: Argument(s) 'always_apply' are not valid for transform Resize
#   A.Resize(height=cfg.size, width=cfg.size, always_apply=True),
# <ipython-input-16-bdca82284c5d>:30: UserWarning: Argument(s) 'always_apply' are not valid for transform Normalize
#   A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0, always_apply=True),
# Generating Image Embeddings:   0%|          | 0/1618 [00:00<?, ?it/s]
# Generated 1618 unique image embeddings.
# Generating embeddings for 8090 captions...
# Generating Text Embeddings:   0%|          | 0/253 [00:00<?, ?it/s]
# Generated 8090 text embeddings.
# Image embeddings saved to /content/sample_data/Flickr8k/final_embeddings/final_image_embeddings.pt
# Text embeddings saved to /content/sample_data/Flickr8k/final_embeddings/final_text_embeddings.pt

# %% [markdown]
# ### Block 6: Retrieval Accuracy Calculation (Using Dumped Embeddings)

# %%
print("\n--- Preparing for Retrieval Accuracy Calculation ---")

# Top-K values for evaluation
TOP_K_VALUES_EVAL = list(range(1, 6)) # k from 1 to 5

# --- Metric Helper Functions (should be defined if not already in scope from Block 2) ---
# Assuming AvgMeter, get_lr are defined. We need compute_top_k_metrics, etc. for retrieval.

def compute_top_k_retrieval_metrics(ranked_keys, ground_truth_keys, current_top_k_values_list):
    result = {k: {"accuracy": 0, "precision": 0, "recall": 0} for k in current_top_k_values_list}
    ground_truth_set = set(ground_truth_keys)
    if not ground_truth_set:
        return result # All metrics remain 0
    for k_val in current_top_k_values_list:
        top_k = ranked_keys[:k_val]
        hits = len(set(top_k) & ground_truth_set)
        result[k_val]["accuracy"] = 1 if hits > 0 else 0
        result[k_val]["precision"] = hits / k_val if k_val > 0 else 0
        result[k_val]["recall"] = hits / len(ground_truth_set)
    return result

def accumulate_retrieval_metrics(overall_metrics_dict, current_query_metrics_dict):
    for k_val in current_query_metrics_dict:
        for metric_name in current_query_metrics_dict[k_val]:
            overall_metrics_dict[k_val][metric_name] += current_query_metrics_dict[k_val][metric_name]

def init_retrieval_metrics_accumulator(current_top_k_values_list):
    return {k: {"accuracy": 0, "precision": 0, "recall": 0} for k in current_top_k_values_list}

def report_retrieval_metrics(title, accumulated_metrics_dict, total_valid_queries_count, current_top_k_values_list):
    print(f"\n--- {title} Retrieval Results ({total_valid_queries_count} Queries) ---")
    if total_valid_queries_count == 0:
        print("No valid queries were processed.")
        return
    for k_val in current_top_k_values_list:
        acc = accumulated_metrics_dict[k_val]["accuracy"] / total_valid_queries_count
        prec = accumulated_metrics_dict[k_val]["precision"] / total_valid_queries_count
        rec = accumulated_metrics_dict[k_val]["recall"] / total_valid_queries_count
        print(f"Top-{k_val}: Accuracy = {acc:.4f} | Precision = {prec:.4f} | Recall = {rec:.4f}")
# Out:
# --- Preparing for Retrieval Accuracy Calculation ---

# %%
# --- Main Evaluation Function using Loaded Embeddings ---
def run_final_retrieval_evaluation(
    image_embeddings_dict_loaded,
    text_embeddings_dict_loaded,
    top_k_list,
    calc_device="cpu" # Device for cosine similarity calculation
):
    if not image_embeddings_dict_loaded or not text_embeddings_dict_loaded:
        print("Error: Loaded image or text embeddings dictionary is empty. Cannot proceed with evaluation.")
        return

    print("Preparing matrices for final evaluation...")
    image_ids_eval_list = list(image_embeddings_dict_loaded.keys())
    img_matrix_list = [image_embeddings_dict_loaded[id_].unsqueeze(0).to(calc_device) if image_embeddings_dict_loaded[id_].ndim==1 else image_embeddings_dict_loaded[id_].to(calc_device) for id_ in image_ids_eval_list]
    image_matrix_eval = torch.cat(img_matrix_list, dim=0).cpu().numpy()

    caption_keys_eval_list = list(text_embeddings_dict_loaded.keys())
    txt_matrix_list = [text_embeddings_dict_loaded[id_].unsqueeze(0).to(calc_device) if text_embeddings_dict_loaded[id_].ndim==1 else text_embeddings_dict_loaded[id_].to(calc_device) for id_ in caption_keys_eval_list]
    text_matrix_eval = torch.cat(txt_matrix_list, dim=0).cpu().numpy()

    print(f"Evaluation Image matrix shape: {image_matrix_eval.shape}")
    print(f"Evaluation Text matrix shape: {text_matrix_eval.shape}")

    gt_img_to_capkeys = defaultdict(list)
    gt_capkey_to_imgid = {}
    for cap_key in caption_keys_eval_list:
        try:
            img_id_part = cap_key.split('_cap_')[0]
            gt_img_to_capkeys[img_id_part].append(cap_key)
            gt_capkey_to_imgid[cap_key] = img_id_part
        except IndexError: continue
    print(f"Built GT map for {len(gt_img_to_capkeys)} images for evaluation.")

    # 1. Image -> Text Retrieval
    if image_matrix_eval.size > 0 and text_matrix_eval.size > 0:
        i2t_metrics = init_retrieval_metrics_accumulator(top_k_list)
        i2t_queries = 0
        for idx, img_id in enumerate(tqdm(image_ids_eval_list, desc="Eval: Img2Txt")):
            if img_id not in gt_img_to_capkeys: continue
            query_img_vec = image_matrix_eval[idx].reshape(1, -1)
            sims = cosine_similarity(query_img_vec, text_matrix_eval)[0]
            ranked_indices = np.argsort(sims)[::-1]
            ranked_caps = [caption_keys_eval_list[i] for i in ranked_indices]
            gt_caps = gt_img_to_capkeys[img_id]
            metrics = compute_top_k_retrieval_metrics(ranked_caps, gt_caps, top_k_list)
            accumulate_retrieval_metrics(i2t_metrics, metrics)
            i2t_queries += 1
        report_retrieval_metrics("Image-to-Text (Final Eval)", i2t_metrics, i2t_queries, top_k_list)

    # 2. Text -> Text Retrieval
    if text_matrix_eval.size > 0:
        t2t_metrics = init_retrieval_metrics_accumulator(top_k_list)
        t2t_queries = 0
        for idx, cap_key_query in enumerate(tqdm(caption_keys_eval_list, desc="Eval: Txt2Txt")):
            img_id_query = gt_capkey_to_imgid.get(cap_key_query)
            if not img_id_query: continue
            query_txt_vec = text_matrix_eval[idx].reshape(1, -1)
            sims = cosine_similarity(query_txt_vec, text_matrix_eval)[0]
            sims[idx] = -1e9 # Exclude self
            ranked_indices = np.argsort(sims)[::-1]
            ranked_caps = [caption_keys_eval_list[i] for i in ranked_indices]
            gt_caps = [ck for ck in gt_img_to_capkeys.get(img_id_query, []) if ck != cap_key_query]
            metrics = compute_top_k_retrieval_metrics(ranked_caps, gt_caps, top_k_list)
            accumulate_retrieval_metrics(t2t_metrics, metrics)
            t2t_queries +=1
        report_retrieval_metrics("Text-to-Text (Final Eval)", t2t_metrics, t2t_queries, top_k_list)

    # 3. Text -> Image Retrieval
    if text_matrix_eval.size > 0 and image_matrix_eval.size > 0:
        t2i_metrics = init_retrieval_metrics_accumulator(top_k_list)
        t2i_queries = 0
        for idx, cap_key_query in enumerate(tqdm(caption_keys_eval_list, desc="Eval: Txt2Img")):
            gt_img_id = gt_capkey_to_imgid.get(cap_key_query)
            if not gt_img_id or gt_img_id not in image_ids_eval_list : continue
            query_txt_vec = text_matrix_eval[idx].reshape(1, -1)
            sims = cosine_similarity(query_txt_vec, image_matrix_eval)[0]
            ranked_indices = np.argsort(sims)[::-1]
            ranked_imgs = [image_ids_eval_list[i] for i in ranked_indices]
            metrics = compute_top_k_retrieval_metrics(ranked_imgs, [gt_img_id], top_k_list)
            accumulate_retrieval_metrics(t2i_metrics, metrics)
            t2i_queries += 1
        report_retrieval_metrics("Text-to-Image (Final Eval)", t2i_metrics, t2i_queries, top_k_list)
    print("\n✅ Final Retrieval Accuracy Calculation Complete.")

# %%
from sklearn.metrics.pairwise import cosine_similarity
# --- Example Usage of Final Evaluation (after Block 5 saves embeddings) ---
if __name__ == '__main__': # This check ensures this part only runs when script is executed directly
    # Paths where embeddings were saved by Block 5
    SAVED_IMG_EMB_PATH = "/content/sample_data/Flickr8k/final_embeddings/final_image_embeddings.pt"
    SAVED_TXT_EMB_PATH = "/content/sample_data/Flickr8k/final_embeddings/final_text_embeddings.pt"

    print(f"\n--- Running Final Retrieval Accuracy Calculation Example ---")

    loaded_final_image_embeddings = {}
    loaded_final_text_embeddings = {}

    if os.path.exists(SAVED_IMG_EMB_PATH):
        loaded_final_image_embeddings = torch.load(SAVED_IMG_EMB_PATH, map_location='cpu')
        print(f"Loaded {len(loaded_final_image_embeddings)} final image embeddings.")
    else:
        print(f"Error: Final Image embeddings file not found at {SAVED_IMG_EMB_PATH}.")

    if os.path.exists(SAVED_TXT_EMB_PATH):
        loaded_final_text_embeddings = torch.load(SAVED_TXT_EMB_PATH, map_location='cpu')
        print(f"Loaded {len(loaded_final_text_embeddings)} final text embeddings.")
    else:
        print(f"Error: Final Text embeddings file not found at {SAVED_TXT_EMB_PATH}.")

    if loaded_final_image_embeddings and loaded_final_text_embeddings:
        run_final_retrieval_evaluation(
            image_embeddings_dict_loaded=loaded_final_image_embeddings,
            text_embeddings_dict_loaded=loaded_final_text_embeddings,
            top_k_list=TOP_K_VALUES_EVAL, # k=1 to 5
            calc_device = cfg.device # Use device from cfg for calculations if GPU available
        )
    else:
        print("Cannot run final evaluation due to missing loaded embeddings.")
# Out:
# --- Running Final Retrieval Accuracy Calculation Example ---
# Error: Final Image embeddings file not found at /content/sample_data/Flickr8k/final_embeddings/final_image_embeddings.pt.
# Error: Final Text embeddings file not found at /content/sample_data/Flickr8k/final_embeddings/final_text_embeddings.pt.
# Cannot run final evaluation due to missing loaded embeddings.

# %%
# !pip freeze > "/content/sample_data/Flickr8k/requirements.txt"
